# %%
import firebase_admin
from firebase_admin import credentials

cred = credentials.Certificate('themacrodiet-s-firebase-adminsdk-f0h78-30db3d9e86.json')
default_app = firebase_admin.initialize_app(cred)

# %%
from firebase_admin import firestore
db = firestore.client()

# %%
db.collection(u'TheMacroDiet/Users/Configuration')

# %%
userIds = [] 
users = db.collection(u'TheMacroDiet/Production/Users').stream()

for user in users:
    userIds.append(user.id)
    #print(f'{user.id} => {user.to_dict()}')

print(userIds)
# Out:
# ['2WX0dbnc79hvsJJk24ttWsINhob2', 'CluQ8oRaLbT4zzpaD1XvwwZHeBh2', 'NiiCO6k43kQhJadKi101xKB5CJY2', 'sqoUfJa3JcRlA8a6fdMJrE6WFk92', 'tONvZlE5VxTsml3ORJosmldGnc72', 'tk0lGGffPVYDZ2C0HghVkiHTs0y2', 'wdCxePmI06TdtybleLe0MggGW2f2', 'ywn6oyiksBOvxrjXosG5VTUXipk1']

# %%
for userId in userIds:
    print(db.collection(u'TheMacroDiet/Production/Users').document(userId).get().to_dict())
# Out:
# {'Options': {'UseOnlyPersonalDb': False, 'DarkMode': False}, 'Sizes': {'DailyEntries': 0}}
# {'Sizes': {'DailyEntries': 384}, 'Options': {'DarkMode': True, 'UseOnlyPersonalDb': False}}
# {'Options': {'DarkMode': False, 'UseOnlyPersonalDb': False}, 'Sizes': {'DailyEntries': 0}}
# {'Sizes': {'DailyEntries': 0}, 'Options': {'UseOnlyPersonalDb': False, 'DarkMode': True}}
# {'Options': {'DarkMode': False, 'UseOnlyPersonalDb': True}, 'Sizes': {'DailyEntries': 0}}
# {'Sizes': {'DailyEntries': 0}, 'Options': {'UseOnlyPersonalDb': False, 'DarkMode': False}}
# {'Sizes': {'DailyEntries': 0}, 'Options': {'UseOnlyPersonalDb': False, 'DarkMode': True}}
# {'Sizes': {'DailyEntries': 0}, 'Options': {'UseOnlyPersonalDb': False, 'DarkMode': False}}

# %%
for userId in userIds:
    print("For user :" + userId)
    print("-------------------------------\n")
    userDailyEntries = db.collection(u'TheMacroDiet/Production/Users/'+userId+'/DailyEntries').stream()
    for userDailyEntry in userDailyEntries:       
        #print(userId +"--->"+ userDailyEntry.id)
        entries = db.collection(u'TheMacroDiet/Production/Users/'+userId+'/DailyEntries/'+userDailyEntry.id+'/Entries').stream()
        entrySize = 0
        for entry in entries:
            entrySize += 1
        print(userId +", "+ userDailyEntry.id +", "+str(entrySize))
# Out:
# For:2WX0dbnc79hvsJJk24ttWsINhob2
# -------------------------------
#
# For:CluQ8oRaLbT4zzpaD1XvwwZHeBh2
# -------------------------------
#
# CluQ8oRaLbT4zzpaD1XvwwZHeBh2, 2021-05-16, 25
# CluQ8oRaLbT4zzpaD1XvwwZHeBh2, 2021-05-17, 26
# CluQ8oRaLbT4zzpaD1XvwwZHeBh2, 2021-05-18, 21
# CluQ8oRaLbT4zzpaD1XvwwZHeBh2, 2021-05-19, 22
# CluQ8oRaLbT4zzpaD1XvwwZHeBh2, 2021-05-20, 22
# CluQ8oRaLbT4zzpaD1XvwwZHeBh2, 2021-05-21, 20
# CluQ8oRaLbT4zzpaD1XvwwZHeBh2, 2021-05-22, 13
# CluQ8oRaLbT4zzpaD1XvwwZHeBh2, 2021-05-23, 20
# CluQ8oRaLbT4zzpaD1XvwwZHeBh2, 2021-05-24, 25
# CluQ8oRaLbT4zzpaD1XvwwZHeBh2, 2021-05-25, 23
# CluQ8oRaLbT4zzpaD1XvwwZHeBh2, 2021-05-26, 21
# CluQ8oRaLbT4zzpaD1XvwwZHeBh2, 2021-05-27, 20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-cd5868c8d815> in <module>
# ...
