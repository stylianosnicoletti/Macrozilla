# %%
import pandas as pd
foods = pd.read_json('themacrodiet-s-export.json')

# %%
foods
# Out:
#                      -M3ZD20Kqf74j5J1oFUd           -M3ZDExHO7Eyo8hahwgv  \
# Calories                              576                            596
# Carbohydrates                          22                           11.6
# Fats                                   49                           46.0
# Name                              Almonds  Peanut Butter Meridian Smooth
# ServingAmount                         100                            100
# ServingUnit                         Grams                          Grams
# ServingUnitShortCode                    g                              g
# Protein                                21                           29.6
# Saturated                             3.7                            8.2
#
#                          -M3ZDQVX9NTW4hqzCtU5  -M3ZDZ6ASOOpPcGC6qBf  \
# Calories                                  625                   106
# Carbohydrates                             7.4                     0
# Fats                                       52                   1.1
# Name                  Almond Butter Pip & Nut  Chicken Breast Tesco
# ServingAmount                             100                   100
# ServingUnit                             Grams                 Grams
# ServingUnitShortCode                        g                     g
# Protein                                    26                    24
# Saturated                                   4                   0.3
#
#                                      -M3ZDifC1k4ByVH7ZhQW  \
# Calories                                               16
# Carbohydrates                                         0.2
# Fats                                                  1.6
# Name                  Koko Dairy Free Unsweetened Calcium
# ServingAmount                                         100
# ServingUnit                                         Grams
# ServingUnitShortCode                                    g
# Protein                                               0.2
# Saturated                                             1.4
#
#                      -M3ZDpXl5Uox77_5naZu      -M3ZDwbSq4sij7pYTtHE  \
# Calories                               16                       360
# Carbohydrates                         3.6                       7.5
# Fats                                  0.1                       1.1
# Name                             Cucumber  ISO100 Gourmet Chocolate
# ServingAmount                         100                       100
# ServingUnit                         Grams                     Grams
# ServingUnitShortCode                    g                         g
# Protein                               0.7                        78
# Saturated                             0.1                       0.6
#
#                                             -M3ZE3F74fSau_g7nkwb  \
# Calories                                                     355
# Carbohydrates                                               0.36
# Fats                                                        0.99
# Name                  ISO-XP Applied Nutrition Chocolate Dessert
# ServingAmount                                                100
# ServingUnit                                                Grams
# ServingUnitShortCode                                           g
# Protein                                                       90
# Saturated                                                   0.04
#
#                                             -M3ZEDwJFal6TZ42fcUJ  \
# Calories                                                      64
# Carbohydrates                                                 12
# Fats                                                         0.1
# Name                  Ketchup Heinz Tomato 50% Less Sugar & Salt
# ServingAmount                                                100
# ServingUnit                                                Grams
# ServingUnitShortCode                                           g
# Protein                                                      1.4
# Saturated                                                      0
#
#                           -M3ZEMbwp863DXtRkhHZ  ... -MWF5HfHXJFn3xgJmaFc  \
# Calories                                    74  ...                  244
# Carbohydrates                             15.6  ...                    0
# Fats                                       0.3  ...                   14
# Name                  Blueberries Frozen Tesco  ...    Sirloin Steak Raw
# ServingAmount                              100  ...                  100
# ServingUnit                              Grams  ...                Grams
# ServingUnitShortCode                         g  ...                    g
# Protein                                    0.8  ...                   27
# Saturated                                  0.1  ...                    6
#
#                                     -MWJeYFBh6yhoFhTkQm9  \
# Calories                                             375
# Carbohydrates                                        5.2
# Fats                                                 1.6
# Name                  BioTechUSA Iso Whey Zero Pistachio
# ServingAmount                                        100
# ServingUnit                                        Grams
# ServingUnitShortCode                                   g
# Protein                                               84
# Saturated                                              1
#
#                                       -MWKdFHzTGTiiKWHrb1j  \
# Calories                                               385
# Carbohydrates                                            5
# Fats                                                   5.5
# Name                  BioTechUSA Pure Whey Cookies & Cream
# ServingAmount                                          100
# ServingUnit                                          Grams
# ServingUnitShortCode                                     g
# Protein                                                 78
# Saturated                                              3.9
#
#                          -MXbjDW_rHcZt1lZNP2O          -MY5gVYyHvJZlE4_iz2T  \
# Calories                                   99                           112
# Carbohydrates                               0                             0
# Fats                                      2.5                          1.07
# Name                  Shrimps Jinga Ocean Sea  Tuna Sevyco In Water Drained
# ServingAmount                             100                           100
# ServingUnit                             Grams                         Grams
# ServingUnitShortCode                        g                             g
# Protein                                  18.6                         22.82
# Saturated                                 0.6                          0.79
#
#                                      -MYf6frTF8s_J8jyk8BY  \
# Calories                                              277
# Carbohydrates                                         5.1
# Fats                                                   28
# Name                  Fresh Cream Vegetable Charalambides
# ServingAmount                                         100
# ServingUnit                                   Milliliters
# ServingUnitShortCode                                   ml
# Protein                                               0.8
# Saturated                                              28
#
#                                          -MYpT6xtPJWiM7adxrno  \
# Calories                                                  185
# Carbohydrates                                             5.5
# Fats                                                       17
# Name                  Fresh Cream Light Charalambides 17% Fat
# ServingAmount                                             100
# ServingUnit                                       Milliliters
# ServingUnitShortCode                                       ml
# Protein                                                   3.5
# Saturated                                                  12
#
#                           -MYpTLTGGu6EqX6w9DKA -MZ4YnDcGuLa4QIJpYf5  \
# Calories                                    18                  119
# Carbohydrates                               .9                  4.7
# Fats                                        .2                  9.4
# Name                  Mushrooms Sliced Premier       Tzatziki Tesco
# ServingAmount                              100                  100
# ServingUnit                              Grams                Grams
# ServingUnitShortCode                         g                    g
# Protein                                    2.1                  3.6
# Saturated                                    0                  4.5
#
#                      -MZ4a3LDuXBeQi_lO8MQ
# Calories                               97
# Carbohydrates                           0
# Fats                                   14
# Name                              Tequila
# ServingAmount                           1
# ServingUnit                         Shots
# ServingUnitShortCode                 shot
# Protein                                 0
# Saturated                              14
#
# [9 rows x 389 columns]

# %%
foods = foods.T

# %%
foods
# Out:
#                      Calories Carbohydrates  Fats  \
# -M3ZD20Kqf74j5J1oFUd      576            22    49
# -M3ZDExHO7Eyo8hahwgv      596          11.6  46.0
# -M3ZDQVX9NTW4hqzCtU5      625           7.4    52
# -M3ZDZ6ASOOpPcGC6qBf      106             0   1.1
# -M3ZDifC1k4ByVH7ZhQW       16           0.2   1.6
# ...                       ...           ...   ...
# -MYf6frTF8s_J8jyk8BY      277           5.1    28
# -MYpT6xtPJWiM7adxrno      185           5.5    17
# -MYpTLTGGu6EqX6w9DKA       18            .9    .2
# -MZ4YnDcGuLa4QIJpYf5      119           4.7   9.4
# -MZ4a3LDuXBeQi_lO8MQ       97             0    14
#
#                                                          Name ServingAmount  \
# -M3ZD20Kqf74j5J1oFUd                                  Almonds           100
# -M3ZDExHO7Eyo8hahwgv            Peanut Butter Meridian Smooth           100
# -M3ZDQVX9NTW4hqzCtU5                  Almond Butter Pip & Nut           100
# -M3ZDZ6ASOOpPcGC6qBf                     Chicken Breast Tesco           100
# -M3ZDifC1k4ByVH7ZhQW      Koko Dairy Free Unsweetened Calcium           100
# ...                                                       ...           ...
# -MYf6frTF8s_J8jyk8BY      Fresh Cream Vegetable Charalambides           100
# -MYpT6xtPJWiM7adxrno  Fresh Cream Light Charalambides 17% Fat           100
# -MYpTLTGGu6EqX6w9DKA                 Mushrooms Sliced Premier           100
# -MZ4YnDcGuLa4QIJpYf5                           Tzatziki Tesco           100
# -MZ4a3LDuXBeQi_lO8MQ                                  Tequila             1
#
#                       ServingUnit ServingUnitShortCode Protein Saturated
# -M3ZD20Kqf74j5J1oFUd        Grams                    g      21       3.7
# -M3ZDExHO7Eyo8hahwgv        Grams                    g    29.6       8.2
# -M3ZDQVX9NTW4hqzCtU5        Grams                    g      26         4
# -M3ZDZ6ASOOpPcGC6qBf        Grams                    g      24       0.3
# -M3ZDifC1k4ByVH7ZhQW        Grams                    g     0.2       1.4
# ...                           ...                  ...     ...       ...
# -MYf6frTF8s_J8jyk8BY  Milliliters                   ml     0.8        28
# -MYpT6xtPJWiM7adxrno  Milliliters                   ml     3.5        12
# -MYpTLTGGu6EqX6w9DKA        Grams                    g     2.1         0
# -MZ4YnDcGuLa4QIJpYf5        Grams                    g     3.6       4.5
# -MZ4a3LDuXBeQi_lO8MQ        Shots                 shot       0        14
#
# [389 rows x 9 columns]

# %%
foods.ServingUnit.unique()
# Out:
# array(['Grams', 'Burgers', 'Milliliters', 'Breasts', 'Candys',
#        'Collins glasses', 'Servings', 'Slices', 'Chips', 'Doughnuts',
#        'Dishes', 'Wings', 'Pieces', 'Bars', 'Sachets', 'Cookies',
#        'Fruits', 'Packets', 'Pancakes', 'Shots'], dtype=object)

# %%
foods.ServingUnitShortCode.unique()
# Out:
# array(['g', 'burger', 'ml', 'breast', 'candy', 'collins glass', 'serving',
#        'slice', 'chips', 'doughnut', 'dish', 'wing', 'piece', 'bar',
#        'sachet', 'cookie', 'fruit', 'packet', 'pancake', 'shot'],
#       dtype=object)

# %%
import firebase_admin
from firebase_admin import credentials

cred = credentials.Certificate('themacrodiet-s-firebase-adminsdk-f0h78-30db3d9e86.json')
default_app = firebase_admin.initialize_app(cred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-0952b07e6d84> in <module>
#       3
#       4 cred = credentials.Certificate('themacrodiet-s-firebase-adminsdk-f0h78-30db3d9e86.json')
# ----> 5 default_app = firebase_admin.initialize_app(cred)
#       6
#
# ~/.local/lib/python3.8/site-packages/firebase_admin/__init__.py in initialize_app(credential, options, name)
#      69
#      70     if name == _DEFAULT_APP_NAME:
# ---> 71         raise ValueError((
#      72             'The default Firebase app already exists. This means you called '
#      73             'initialize_app() more than once without providing an app name as '
#
# ValueError: The default Firebase app already exists. This means you called initialize_app() more than once without providing an app name as the second argument. In most cases you only need to call initialize_app() once. But if you do want to initialize multiple apps, pass a second argument to initialize_app() to give each app a unique name.

# %%
from firebase_admin import firestore
db = firestore.client()

# %%
doc_ref = db.collection(u'TheMacroDiet/Production/GlobalVariables').document(u'ServingUnits')

doc = doc_ref.get()
if doc.exists:
    print(f'Document data: {doc.to_dict()}')
    current_Serving_Units= doc
else:
    print(u'No such document!')
# Out:
# Document data: {'Milligrams': {'ShortCodePlural': 'mg', 'ShortCode': 'mg'}}

# %%
current_Serving_Units.to_dict()
# Out:
# {'Milligrams': {'ShortCodePlural': 'mg', 'ShortCode': 'mg'}}

# %%
servingUnitsDoc = {
   # u'stringExample': u'Hello, World!',
   # u'booleanExample': True,
   # u'numberExample': 3.14159265,
   # u'dateExample': datetime.datetime.now(),
   # u'arrayExample': [5, True, u'hello'],
   # u'nullExample': None,
    u'Grams': {
        u'ShortCode': u'g',
        u'ShortCodePlural': u'g'
    },
    u'Milligrams': {
        u'ShortCode': u'mg',
        u'ShortCodePlural': u'mg'
    },
    u'Pieces': {
        u'ShortCode': u'piece',
        u'ShortCodePlural': u'pieces'
    },
    u'Milliliters ': {
        u'ShortCode': u'ml',
        u'ShortCodePlural': u'ml'
    },
    u'Product': {
        u'ShortCode': u'product',
        u'ShortCodePlural': u'products'
    },
    u'Burgers': {
        u'ShortCode': u'burger',
        u'ShortCodePlural': u'burgers'
    },
    u'Breasts': {
        u'ShortCode': u'breast',
        u'ShortCodePlural': u'breasts'
    },
    u'Candys': {
        u'ShortCode': u'candy',
        u'ShortCodePlural': u'candys'
    },
    u'Collins glasses': {
        u'ShortCode': u'collins glass',
        u'ShortCodePlural': u'collins glasses'
    },
    u'Servings': {
        u'ShortCode': u'serving',
        u'ShortCodePlural': u'servings'
    },
    u'Slices': {
        u'ShortCode': u'slice',
        u'ShortCodePlural': u'slices'
    },
    u'Chips': {
        u'ShortCode': u'chip',
        u'ShortCodePlural': u'chips'
    },
    u'Doughnuts': {
        u'ShortCode': u'doughnut',
        u'ShortCodePlural': u'doughnuts'
    },
    u'Dishes': {
        u'ShortCode': u'dish',
        u'ShortCodePlural': u'dishes'
    },
    u'Wings': {
        u'ShortCode': u'wing',
        u'ShortCodePlural': u'wings'
    },
    u'Bars': {
        u'ShortCode': u'bar',
        u'ShortCodePlural': u'bars'
    },
    u'Sachets': {
        u'ShortCode': u'sachet',
        u'ShortCodePlural': u'sachets'
    },
    u'Cookies': {
        u'ShortCode': u'cookie',
        u'ShortCodePlural': u'cookies'
    },
    u'Fruits': {
        u'ShortCode': u'fruit',
        u'ShortCodePlural': u'fruits'
    },
    u'Packets': {
        u'ShortCode': u'packet',
        u'ShortCodePlural': u'packets'
    },
    u'Pancakes': {
        u'ShortCode': u'pancake',
        u'ShortCodePlural': u'pancakes'
    },
    u'Shots': {
        u'ShortCode': u'shot',
        u'ShortCodePlural': u'shots'
    }
}

# %%
servingUnitsDoc
# Out:
# {'Grams': {'ShortCode': 'g', 'ShortCodePlural': 'g'},
#  'Milligrams': {'ShortCode': 'mg', 'ShortCodePlural': 'mg'},
#  'Pieces': {'ShortCode': 'piece', 'ShortCodePlural': 'pieces'},
#  'Milliliters ': {'ShortCode': 'ml', 'ShortCodePlural': 'ml'},
#  'Product': {'ShortCode': 'product', 'ShortCodePlural': 'products'},
#  'Burgers': {'ShortCode': 'burger', 'ShortCodePlural': 'burgers'},
#  'Breasts': {'ShortCode': 'breast', 'ShortCodePlural': 'breasts'},
#  'Candys': {'ShortCode': 'candy', 'ShortCodePlural': 'candys'},
#  'Collins glasses': {'ShortCode': 'collins glass',
#   'ShortCodePlural': 'collins glasses'},
#  'Servings': {'ShortCode': 'serving', 'ShortCodePlural': 'servings'},
#  'Slices': {'ShortCode': 'slice', 'ShortCodePlural': 'slices'},
#  'Chips': {'ShortCode': 'chip', 'ShortCodePlural': 'chips'},
#  'Doughnuts': {'ShortCode': 'doughnut', 'ShortCodePlural': 'doughnuts'},
#  'Dishes': {'ShortCode': 'dish', 'ShortCodePlural': 'dishes'},
#  'Wings': {'ShortCode': 'wing', 'ShortCodePlural': 'wings'},
#  'Bars': {'ShortCode': 'bar', 'ShortCodePlural': 'bars'},
#  'Sachets': {'ShortCode': 'sachet', 'ShortCodePlural': 'sachets'},
#  'Cookies': {'ShortCode': 'cookie', 'ShortCodePlural': 'cookies'},
#  'Fruits': {'ShortCode': 'fruit', 'ShortCodePlural': 'fruits'},
#  'Packets': {'ShortCode': 'packet', 'ShortCodePlural': 'packets'},
#  'Pancakes': {'ShortCode': 'pancake', 'ShortCodePlural': 'pancakes'},
#  'Shots': {'ShortCode': 'shot', 'ShortCodePlural': 'shots'}}

# %%
db.collection(u'TheMacroDiet/Production/GlobalVariables').document(u'ServingUnits').set(servingUnitsDoc);

# %%
for ind in foods.index:
    name = foods['Name'][ind]
    foodData = {
        u'Name': name.encode('utf-8','ignore').decode('utf-8'),
        u'Calories': int(foods['Calories'][ind]),
        u'Carbohydrates': float(foods['Carbohydrates'][ind]),
        u'Fats': float(foods['Fats'][ind]),
        u'Protein': float(foods['Protein'][ind]),
        u'Saturated': float(foods['Saturated'][ind]),
        u'ServingAmount': float(foods['ServingAmount'][ind]),
        u'ServingUnit': foods['ServingUnit'][ind],
        u'ServingUnitShortCode': foods['ServingUnitShortCode'][ind],
       # u'booleanExample': True,
       # u'numberExample': 3.14159265,
       # u'dateExample': datetime.datetime.now(),
       # u'arrayExample': [5, True, u'hello'],
       # u'nullExample': None,
    }
    doc_ref = db.collection(u'TheMacroDiet/Production/GlobalFoodDatabase').add(foodData)

# %%
foodData
# Out:
# {'Name': 'Almond Butter Pip & Nut',
#  'Calories': 625,
#  'Carbohydrates': 7.4,
#  'Fats': 52.0,
#  'Protein': 26.0,
#  'Saturated': 4.0,
#  'ServingAmount': 100.0,
#  'ServingUnit': 'Grams',
#  'ServingUnitShortCode': 'g'}

# %%
aaaaaa
# Out:
# [<google.cloud.firestore_v1.base_document.DocumentSnapshot at 0x7f44c0f1fdf0>,
#  <google.cloud.firestore_v1.base_document.DocumentSnapshot at 0x7f44c0f1fd30>]
